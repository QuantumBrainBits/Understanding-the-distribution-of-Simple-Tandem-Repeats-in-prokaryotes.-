# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
from collections import Counter

# %%
df = pd.read_csv("./Archaea_table.tsv", sep="\t")
df.head()
# Out:
#         MSDBID               OrganismName  CommonName   TaxID  \
# 0  MSDBG000175        Acidianus brierleyi         NaN   41673
# 1  MSDBG000184       Acidiplasma aeolicum         NaN  507754
# 2  MSDBG000185  Acidiplasma cupricumulans         NaN  312540
# 3  MSDBG000464           Aeropyrum pernix         NaN   56636
# 4  MSDBG000841     Archaeoglobus fulgidus         NaN    2234
#
#                Strain  Kingdom          Group             SubGroup   Size  \
# 0     strain=DSM 1651  Archaea     TACK group        Crenarchaeota  2.947
# 1           strain=VT  Archaea  Euryarchaeota  Diaforarchaea group  1.779
# 2          strain=BH2  Archaea  Euryarchaeota  Diaforarchaea group  1.731
# 3  strain=YK1-12-2013  Archaea     TACK group        Crenarchaeota  1.601
# 4                 NaN  Archaea  Euryarchaeota         Archaeoglobi  2.037
#
#       GC Annotation    AssemblyLevel  Source          Build  \
# 0  31.90          Y  Complete Genome  RefSeq    ASM320183v1
# ...

# %%
df.shape
# Out:
# (1554, 15)

# %%
df1 = pd.read_csv("/home/ccmb/Desktop/SSRs_Prokaryotes_Analysis/Jupyter_Notebook/Descriptive_stats/Archeae_Datasetv1.tsv", sep="\t")
df1.head(20)
# Out:
#     Unnamed: 0  Unnamed: 0.1                      file_name  Kingdom  \
# 0            0             0    GCF_002287175.1_ASM228717v1  Archaea
# 1            1             1            GCF_001458655.1_Mb9  Archaea
# 2            2             2    GCF_002813085.1_ASM281308v1  Archaea
# 3            3             3    GCF_001889405.1_ASM188940v1  Archaea
# 4            4             4   GCF_017875395.1_ASM1787539v1  Archaea
# 5            5             5    GCF_001571405.1_ASM157140v1  Archaea
# 6            6             6   GCF_019263745.1_ASM1926374v1  Archaea
# 7            7             7   GCF_019669945.1_ASM1966994v1  Archaea
# 8            8         29886                    MSDBG021724  Archaea
# 9            9             9  GCF_000765475.1_Mmet_Version1  Archaea
# 10          10         25259                    MSDBG010900  Archaea
# 11          11            11    GCF_004799605.1_ASM479960v1  Archaea
# 12          12            12   GCF_018420015.1_ASM1842001v1  Archaea
# ...

# %%
rclass_rank = {}

# %%
dff = pd.read_csv("/home/ccmb/Desktop/SSRs_Prokaryotes_Analysis/Jupyter_Notebook/Descriptive_stats/FinalArchaea_rankingDataset1.tsv", sep = "\t")

dff.head()
# Out:
#               subgroup  A  AAAAAC  AAAAAG  AAAAAT  AAAAC  AAAACC  AAAACG  \
# 0  Stenosarchaea group -2       3       3       3     -2      -2      -2
# 1         Archaeoglobi -2       1       3       3     -2      -2      -2
# 2    Methanomada group -2      -2       1       3     -2      -2      -2
# 3  Stenosarchaea group -2      -2      -2      -2     -2      -2      -2
# 4        Nanoarchaeota -2      -2       3       3     -2      -2      -2
#
#    AAAACT  AAAAG  ...  CCCG  CCCGCG  CCCGG  CCCGGG  CCG  CCGCG  CCGCGG  CCGG  \
# 0      -2      3  ...    -2      -2     -2      -2   -2     -2      -2    -2
# 1      -2      1  ...    -2      -2     -2      -2   -2     -2      -2    -2
# 2      -2     -2  ...    -2      -2     -2      -2   -2     -2      -2    -2
# 3      -2     -2  ...    -2       1      0      -2    2      0       1    -2
# 4       2      3  ...    -2      -2     -2      -2   -2     -2      -2    -2
#
#    CCGGCG  CG
# 0      -2  -2
# 1      -2  -2
# 2      -2  -2
# ...

# %%
df1.shape
# Out:
# (2110, 17)

# %%
df1.groupby(['SubGroup']).count()
# Out:
#                                       Unnamed: 0  Unnamed: 0.1  file_name  \
# SubGroup
# Archaeoglobi                                  16            16         16
# Candidatus Aenigmarchaeota                    15            15         15
# Candidatus Bathyarchaeota                     42            42         42
# Candidatus Diapherotrites                     12            12         12
# Candidatus Marsarchaeota                      15            15         15
# Candidatus Micrarchaeota                      35            35         35
# Candidatus Pacearchaeota                      41            41         41
# Candidatus Parvarchaeota                      12            12         12
# Candidatus Woesearchaeota                     38            38         38
# Candidatus Wukongarchaeota                    45            45         45
# Crenarchaeota                                163           163        163
# ...
